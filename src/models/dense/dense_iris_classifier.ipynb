# %%
# handle image
import cv2
from matplotlib import pyplot as plt

# utils
import os
import random
import imutils
import numpy as np
import pandas as pd

# machine learning
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

from tensorflow.keras.utils import plot_model

import tensorflow.keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Configurações

# %%
CURRENT_MODEL_VERSION = 1

TYPE_LOSS = "binarycross"

MODEL_LABEL = "dense" 

IMG_SHAPE = (150, 150, 3)
EMBEDDING_DIM = 1024

RESIZED_IMG_SHAPE = (IMG_SHAPE[0], IMG_SHAPE[1])

COLAB_PATH = "drive/MyDrive/"

DATASET_PATH = COLAB_PATH +'datasets/cropped_eyes.csv'

TRAIN_SIZE = 0.7
TEST_SIZE = 0.2
VALIDATION_SIZE = 0.1

BATCH_SIZE = 64
EPOCHS = 120

BASE_OUTPUT = COLAB_PATH + "output"
MODEL_EXTENSION = ".hdf5"

FOLDER = os.path.sep.join([BASE_OUTPUT , MODEL_LABEL])
FOLDER = os.path.sep.join([FOLDER , TYPE_LOSS])
FOLDER = os.path.sep.join([FOLDER,"v{}".format(CURRENT_MODEL_VERSION)])

ACC_PATH = os.path.sep.join([FOLDER,"acc_test.txt"])
MODEL_INFO_PATH = os.path.sep.join([FOLDER,"model_info.txt"])

MODEL_PATH = os.path.sep.join([FOLDER, "siamese_model_{}".format(CURRENT_MODEL_VERSION)])
PLOT_PATH = os.path.sep.join([FOLDER, "plot-{}.png".format(CURRENT_MODEL_VERSION)])
PLOT_FEATURE_ARCHTECTURE_PATH = os.path.sep.join([FOLDER, "feature_extractor_arch-{}.png".format(CURRENT_MODEL_VERSION)])
PLOT_MODEL_ARCHTECTURE_PATH = os.path.sep.join([FOLDER, "model_arch-{}.png".format(CURRENT_MODEL_VERSION)])

SCORES = ['accuracy']

# %%
if not os.path.isdir(FOLDER):
  os.mkdir(FOLDER)

# %% [markdown]
# ### Funções preprocessamento

# %%
def preprocess_image(filename):
  image = cv2.imread(filename)
  image = cv2.resize(image, RESIZED_IMG_SHAPE, interpolation = cv2.INTER_AREA)
  if IMG_SHAPE[2] == 1:
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

  return image

# %%
def preprocess_triplets(images, labels):
  unique_labels = np.unique(labels)
  num_classes = len(unique_labels)
  
  idx = { "{}".format(i) :np.where(labels == i)[0] for i in unique_labels }

  pair_images = []
  pair_labels = []

  for idxA in range(len(images)):

    currentImage = preprocess_image(images[idxA])
    label = labels[idxA]

    idxB = np.random.choice(idx[label])
    posImage = preprocess_image(images[idxB])

    pair_images.append([currentImage, posImage])
    pair_labels.append([1])

    negIdx = np.where(labels != label)[0]
    negImage = preprocess_image(images[np.random.choice(negIdx)])

    pair_images.append([currentImage, negImage])
    pair_labels.append([0])
  
  return (np.array(pair_images), np.array(pair_labels))

# %% [markdown]
# ### Funções NN

# %%
def build_siamese_model(inputShape, embeddingDim=EMBEDDING_DIM):
  inputs = Input(inputShape)
  
  x = Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu")(inputs)
  x = MaxPooling2D(pool_size=(2, 2))(x)
  x = Dropout(0.3)(x)
  
  x = Conv2D(filters=64, kernel_size=(2, 2), padding="same", activation="relu")(x)
  x = MaxPooling2D(pool_size=(2,2))(x)
  x = Dropout(0.3)(x)

  pooledOutput = GlobalAveragePooling2D()(x)
  outputs = Dense(embeddingDim)(pooledOutput)
  
  model = Model(inputs, outputs)
  
  return model

# %%
def build_network():
  imgA = Input(shape=IMG_SHAPE)
  imgB = Input(shape=IMG_SHAPE)
  featureExtractor = build_siamese_model(IMG_SHAPE)
  featsA = featureExtractor(imgA)
  featsB = featureExtractor(imgB)

  distance = Lambda(euclidean_distance)([featsA, featsB])

  x = Dense(64, activation="relu")(distance)
  x = Dropout(0.3)(x)
  x = Dense(32, activation="tanh")(x)
  outputs = Dense(1, activation="sigmoid")(x)

  model = Model(inputs=[imgA, imgB], outputs=outputs)
  return model

# %%
def euclidean_distance(vectors):
  (featsA, featsB) = vectors
  
  sumSquared = K.sum(K.square(featsA - featsB), axis=1,
    keepdims=True)
  
  return K.sqrt(K.maximum(sumSquared, K.epsilon()))

# %%
def plot_training(H, plotPath):
	plt.style.use("ggplot")
	plt.figure()
	plt.plot(H.history["loss"], label="train_loss")
	plt.plot(H.history["val_loss"], label="val_loss")
	plt.plot(H.history["accuracy"], label="train_acc")
	plt.plot(H.history["val_accuracy"], label="val_acc")
	plt.title("Treinamento Loss e Accuracy")
	plt.xlabel("Épocas")
	plt.ylabel("Loss/Accuracy")
	plt.legend(loc="lower left")
	plt.savefig(plotPath)

# %% [markdown]
# ### Criação do modelo

# %%
dataset = pd.read_csv(DATASET_PATH, index_col="Unnamed: 0")

# %%
#dataset = dataset[:][:100]

# %%
(pair_images, pair_labels) = preprocess_triplets(dataset['image_path'],dataset['class'])

# %%
X_train, X_rem, y_train, y_rem = train_test_split(pair_images, pair_labels, test_size=TEST_SIZE + VALIDATION_SIZE)

X_valid, X_test, y_valid, y_test = train_test_split(X_rem,y_rem, test_size=TEST_SIZE)

# %%
print(X_train.shape), print(y_train.shape)
print(X_valid.shape), print(y_valid.shape)
print(X_test.shape), print(y_test.shape)
# Out:
# (2720, 2, 150, 150, 3)
# (2720, 1)
# (932, 2, 150, 150, 3)
# (932, 1)
# (234, 2, 150, 150, 3)
# (234, 1)
# (None, None)

# %%
del(pair_images)
del(pair_labels)

# %%
print("[INFO] building siamese network...")
imgA = Input(shape=IMG_SHAPE)
imgB = Input(shape=IMG_SHAPE)
featureExtractor = build_siamese_model(IMG_SHAPE)
featsA = featureExtractor(imgA)
featsB = featureExtractor(imgB)
# Out:
# [INFO] building siamese network...

# %%
plot_model(featureExtractor,to_file=PLOT_FEATURE_ARCHTECTURE_PATH,show_shapes=True,show_layer_activations=True)

# %%
model = build_network()
plot_model(model,to_file=PLOT_MODEL_ARCHTECTURE_PATH,show_shapes=True,show_layer_activations=True)

# %%
print("[INFO] compiling model...")
model.compile(loss="binary_crossentropy", optimizer="adam",
	metrics=SCORES)
# Out:
# [INFO] compiling model...

# %%
history = model.fit(
                    [X_train[:, 0], X_train[:, 1]], y_train[:],
                    validation_data=([X_valid[:, 0], X_valid[:, 1]], y_valid[:]),
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCH
120
# 43/43 [==============================] - 154s 4s/step - loss: 0.3078 - accuracy: 0.8721 - val_loss: 0.4044 - val_accuracy: 0.8294
# Epoch 78/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.3174 - accuracy: 0.8687 - val_loss: 0.4572 - val_accuracy: 0.8133
# Epoch 79/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.3079 - accuracy: 0.8721 - val_loss: 0.4388 - val_accuracy: 0.8230
# Epoch 80/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.3043 - accuracy: 0.8761 - val_loss: 0.4982 - val_accuracy: 0.8004
# Epoch 81/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2986 - accuracy: 0.8772 - val_loss: 0.4247 - val_accuracy: 0.8369
# Epoch 82/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.3025 - accuracy: 0.8732 - val_loss: 0.4607 - val_accuracy: 0.8026
# Epoch 83/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.3105 - accuracy: 0.8695 - val_loss: 0.4736 - val_accuracy: 0.8122
# Epoch 84/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.3032 - accuracy: 0.8743 - val_loss: 0.4107 - val_accuracy: 0.8380
# Epoch 85/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2885 - accuracy: 0.8794 - val_loss: 0.4609 - val_accuracy: 0.8219
# Epoch 86/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2966 - accuracy: 0.8779 - val_loss: 0.4124 - val_accuracy: 0.8315
# Epoch 87/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.3052 - accuracy: 0.8721 - val_loss: 0.5062 - val_accuracy: 0.8069
# Epoch 88/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.3003 - accuracy: 0.8768 - val_loss: 0.3980 - val_accuracy: 0.8305
# Epoch 89/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2939 - accuracy: 0.8776 - val_loss: 0.4157 - val_accuracy: 0.8262
# Epoch 90/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2868 - accuracy: 0.8831 - val_loss: 0.4171 - val_accuracy: 0.8273
# Epoch 91/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2865 - accuracy: 0.8871 - val_loss: 0.3978 - val_accuracy: 0.8466
# Epoch 92/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2861 - accuracy: 0.8739 - val_loss: 0.4409 - val_accuracy: 0.8251
# Epoch 93/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2938 - accuracy: 0.8757 - val_loss: 0.4649 - val_accuracy: 0.8165
# Epoch 94/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2949 - accuracy: 0.8805 - val_loss: 0.4777 - val_accuracy: 0.8144
# Epoch 95/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2938 - accuracy: 0.8794 - val_loss: 0.4349 - val_accuracy: 0.8337
# Epoch 96/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2957 - accuracy: 0.8750 - val_loss: 0.4192 - val_accuracy: 0.8294
# Epoch 97/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2870 - accuracy: 0.8809 - val_loss: 0.4117 - val_accuracy: 0.8305
# Epoch 98/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2986 - accuracy: 0.8783 - val_loss: 0.4529 - val_accuracy: 0.8101
# Epoch 99/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2723 - accuracy: 0.8919 - val_loss: 0.4489 - val_accuracy: 0.8219
# Epoch 100/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2830 - accuracy: 0.8835 - val_loss: 0.4299 - val_accuracy: 0.8208
# Epoch 101/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2828 - accuracy: 0.8853 - val_loss: 0.4095 - val_accuracy: 0.8294
# Epoch 102/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2803 - accuracy: 0.8787 - val_loss: 0.4400 - val_accuracy: 0.8208
# Epoch 103/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2767 - accuracy: 0.8857 - val_loss: 0.4022 - val_accuracy: 0.8262
# Epoch 104/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2716 - accuracy: 0.9000 - val_loss: 0.4105 - val_accuracy: 0.8358
# Epoch 105/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2807 - accuracy: 0.8882 - val_loss: 0.4131 - val_accuracy: 0.8315
# Epoch 106/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2801 - accuracy: 0.8838 - val_loss: 0.4652 - val_accuracy: 0.8240
# Epoch 107/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2673 - accuracy: 0.8952 - val_loss: 0.4746 - val_accuracy: 0.8208
# Epoch 108/120
# 43/43 [==============================] - 153s 4s/step - loss: 0.2613 - accuracy: 0.8923 - val_loss: 0.4265 - val_accuracy: 0.8326
# Epoch 109/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2844 - accuracy: 0.8846 - val_loss: 0.4162 - val_accuracy: 0.8305
# Epoch 110/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2713 - accuracy: 0.8890 - val_loss: 0.4676 - val_accuracy: 0.8251
# Epoch 111/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2675 - accuracy: 0.8930 - val_loss: 0.4475 - val_accuracy: 0.8230
# Epoch 112/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2642 - accuracy: 0.8938 - val_loss: 0.3989 - val_accuracy: 0.8401
# Epoch 113/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2754 - accuracy: 0.8842 - val_loss: 0.4896 - val_accuracy: 0.8176
# Epoch 114/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2782 - accuracy: 0.8831 - val_loss: 0.4349 - val_accuracy: 0.8230
# Epoch 115/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2675 - accuracy: 0.8982 - val_loss: 0.4441 - val_accuracy: 0.8315
# Epoch 116/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2786 - accuracy: 0.8897 - val_loss: 0.4376 - val_accuracy: 0.8369
# Epoch 117/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2661 - accuracy: 0.8901 - val_loss: 0.5945 - val_accuracy: 0.8026
# Epoch 118/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2631 - accuracy: 0.8985 - val_loss: 0.4056 - val_accuracy: 0.8433
# Epoch 119/120
# 43/43 [==============================] - 155s 4s/step - loss: 0.2540 - accuracy: 0.8985 - val_loss: 0.4575 - val_accuracy: 0.8294
# Epoch 120/120
# 43/43 [==============================] - 154s 4s/step - loss: 0.2596 - accuracy: 0.8938 - val_loss: 0.4529 - val_accuracy: 0.8262

# %%
plot_training(history,PLOT_PATH)

# %% [markdown]
# ### Salvar modelo

# %%
model.save(MODEL_PATH)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %% [markdown]
# ### Recuperar modelo salvo

# %%
model_recovered = load_model(MODEL_PATH)

# %% [markdown]
# ### Aplicar modelo aos dados de teste

# %%
y_pred = model_recovered.predict([X_test[:, 0], X_test[:, 1]])
# Out:
# 8/8 [==============================] - 4s 474ms/step

# %%
mapper_class = lambda value: 1 if value > 0.5 else 0

# %%
y_mapped = [ mapper_class(value) for value in  y_pred]
y_mapped = np.asarray(y_mapped).reshape(-1,1)

# %%
evaluation = abs(y_mapped - y_test)

# %%
acc = (evaluation.shape[0] - sum(evaluation))/evaluation.shape[0]

# %%
acc
# Out:
# array([0.84188034])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

cm= confusion_matrix(y_test, y_mapped)
sn.heatmap(cm, annot=True, fmt="d", cmap="binary")
plt.ylabel('Class Label')
plt.xlabel('Predicted Label')
plt.title('Matriz de confusão')


plt.savefig(FOLDER+'/confusion_matrix.png')

# %%
acc
# Out:
# array([0.84188034])

# %%
with open(ACC_PATH, 'w') as f:
    f.write("acc: {}\n".format(acc))
    f.write("batch size: {}\n".format(BATCH_SIZE))
    f.write("epochs: {}\n".format(EPOCHS))

# %%
with open(MODEL_INFO_PATH, 'w') as f:
    model_recovered.summary(print_fn=lambda x: f.write(x + '\n'))
