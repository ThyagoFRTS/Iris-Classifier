# %%
# handle image
import cv2
from matplotlib import pyplot as plt

# utils
import os
import random
import imutils
import numpy as np
import pandas as pd

# machine learning
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

from tensorflow.keras.utils import plot_model

import tensorflow.keras.backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Configurações

# %%
CURRENT_MODEL_VERSION = 1

TYPE_LOSS = "binarycross"

MODEL_LABEL = "simple" 

IMG_SHAPE = (150, 150, 3)
EMBEDDING_DIM = 1024

RESIZED_IMG_SHAPE = (IMG_SHAPE[0], IMG_SHAPE[1])

COLAB_PATH = "drive/MyDrive/"

DATASET_PATH = COLAB_PATH +'datasets/cropped_eyes.csv'

TRAIN_SIZE = 0.7
TEST_SIZE = 0.2
VALIDATION_SIZE = 0.1

BATCH_SIZE = 64
EPOCHS = 120

BASE_OUTPUT = COLAB_PATH + "output"
MODEL_EXTENSION = ".hdf5"

FOLDER = os.path.sep.join([BASE_OUTPUT , MODEL_LABEL])
FOLDER = os.path.sep.join([FOLDER , TYPE_LOSS])
FOLDER = os.path.sep.join([FOLDER,"v{}".format(CURRENT_MODEL_VERSION)])

ACC_PATH = os.path.sep.join([FOLDER,"acc_test.txt"])
MODEL_INFO_PATH = os.path.sep.join([FOLDER,"model_info.txt"])

MODEL_PATH = os.path.sep.join([FOLDER, "siamese_model_{}".format(CURRENT_MODEL_VERSION)])
PLOT_PATH = os.path.sep.join([FOLDER, "plot-{}.png".format(CURRENT_MODEL_VERSION)])
PLOT_FEATURE_ARCHTECTURE_PATH = os.path.sep.join([FOLDER, "feature_extractor_arch-{}.png".format(CURRENT_MODEL_VERSION)])
PLOT_MODEL_ARCHTECTURE_PATH = os.path.sep.join([FOLDER, "model_arch-{}.png".format(CURRENT_MODEL_VERSION)])

SCORES = ['accuracy']

# %%
if not os.path.isdir(FOLDER):
  os.mkdir(FOLDER)

# %% [markdown]
# ### Funções preprocessamento

# %%
def preprocess_image(filename):
  image = cv2.imread(filename)
  image = cv2.resize(image, RESIZED_IMG_SHAPE, interpolation = cv2.INTER_AREA)
  if IMG_SHAPE[2] == 1:
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

  return image

# %%
def preprocess_triplets(images, labels):
  unique_labels = np.unique(labels)
  num_classes = len(unique_labels)
  
  idx = { "{}".format(i) :np.where(labels == i)[0] for i in unique_labels }

  pair_images = []
  pair_labels = []

  for idxA in range(len(images)):

    currentImage = preprocess_image(images[idxA])
    label = labels[idxA]

    idxB = np.random.choice(idx[label])
    posImage = preprocess_image(images[idxB])

    pair_images.append([currentImage, posImage])
    pair_labels.append([1])

    negIdx = np.where(labels != label)[0]
    negImage = preprocess_image(images[np.random.choice(negIdx)])

    pair_images.append([currentImage, negImage])
    pair_labels.append([0])
  
  return (np.array(pair_images), np.array(pair_labels))

# %% [markdown]
# ### Funções NN

# %%
def build_siamese_model(inputShape, embeddingDim=EMBEDDING_DIM):
  inputs = Input(inputShape)
  
  x = Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu")(inputs)
  x = MaxPooling2D(pool_size=(2, 2))(x)
  x = Dropout(0.3)(x)
  
  x = Conv2D(filters=64, kernel_size=(2, 2), padding="same", activation="relu")(x)
  x = MaxPooling2D(pool_size=(2,2))(x)
  x = Dropout(0.3)(x)

  
  pooledOutput = GlobalAveragePooling2D()(x)
  outputs = Dense(embeddingDim)(pooledOutput)
  
  model = Model(inputs, outputs)
  
  return model

# %%
def build_network():
  imgA = Input(shape=IMG_SHAPE)
  imgB = Input(shape=IMG_SHAPE)
  featureExtractor = build_siamese_model(IMG_SHAPE)
  featsA = featureExtractor(imgA)
  featsB = featureExtractor(imgB)

  distance = Lambda(euclidean_distance)([featsA, featsB])
  outputs = Dense(1, activation="sigmoid")(distance)

  model = Model(inputs=[imgA, imgB], outputs=outputs)
  return model

# %%
def euclidean_distance(vectors):
  (featsA, featsB) = vectors

  sumSquared = K.sum(K.square(featsA - featsB), axis=1,
    keepdims=True)
  return K.sqrt(K.maximum(sumSquared, K.epsilon()))

# %%
def plot_training(H, plotPath):
	plt.style.use("ggplot")
	plt.figure()
	plt.plot(H.history["loss"], label="train_loss")
	plt.plot(H.history["val_loss"], label="val_loss")
	plt.plot(H.history["accuracy"], label="train_acc")
	plt.plot(H.history["val_accuracy"], label="val_acc")
	plt.title("Treinamento Loss e Accuracy")
	plt.xlabel("Épocas")
	plt.ylabel("Loss/Accuracy")
	plt.legend(loc="lower left")
	plt.savefig(plotPath)

# %% [markdown]
# ### Criação do modelo

# %%
dataset = pd.read_csv(DATASET_PATH, index_col="Unnamed: 0")

# %%
#dataset = dataset[:][:100]

# %%
(pair_images, pair_labels) = preprocess_triplets(dataset['image_path'],dataset['class'])

# %%
X_train, X_rem, y_train, y_rem = train_test_split(pair_images, pair_labels, test_size=TEST_SIZE + VALIDATION_SIZE)

X_valid, X_test, y_valid, y_test = train_test_split(X_rem,y_rem, test_size=TEST_SIZE)

# %%
print(X_train.shape), print(y_train.shape)
print(X_valid.shape), print(y_valid.shape)
print(X_test.shape), print(y_test.shape)
# Out:
# (2720, 2, 150, 150, 3)
# (2720, 1)
# (932, 2, 150, 150, 3)
# (932, 1)
# (234, 2, 150, 150, 3)
# (234, 1)
# (None, None)

# %%
del(pair_images)
del(pair_labels)

# %%
print("[INFO] building siamese network...")
imgA = Input(shape=IMG_SHAPE)
imgB = Input(shape=IMG_SHAPE)
featureExtractor = build_siamese_model(IMG_SHAPE)
featsA = featureExtractor(imgA)
featsB = featureExtractor(imgB)
# Out:
# [INFO] building siamese network...

# %%
plot_model(featureExtractor,to_file=PLOT_FEATURE_ARCHTECTURE_PATH,show_shapes=True,show_layer_activations=True)

# %%
model = build_network()
plot_model(model,to_file=PLOT_MODEL_ARCHTECTURE_PATH,show_shapes=True,show_layer_activations=True)

# %%
print("[INFO] compiling model...")
model.compile(loss="binary_crossentropy", optimizer="adam",
	metrics=SCORES)
# Out:
# [INFO] compiling model...

# %%
history = model.fit(
                    [X_train[:, 0], X_train[:, 1]], y_train[:],
                    validation_data=([X_valid[:, 0], X_valid[:, 1]], y_valid[:]),
                    batch_size=BATCH_SIZE, 
                    epochs=EPOCHS)
# Out:
# Epoch 1/120
# 43/43 [==============================] - 245s 6s/step - loss: 1.4567 - accuracy: 0.5063 - val_loss: 0.6855 - val_accuracy: 0.6341
# Epoch 2/120
# 43/43 [==============================] - 244s 6s/step - loss: 0.6654 - accuracy: 0.5092 - val_loss: 0.6655 - val_accuracy: 0.7049
# Epoch 3/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.6389 - accuracy: 0.5364 - val_loss: 0.6439 - val_accuracy: 0.7071
# Epoch 4/120
# 43/43 [==============================] - 248s 6s/step - loss: 0.6282 - accuracy: 0.6070 - val_loss: 0.6406 - val_accuracy: 0.7082
# Epoch 5/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.6199 - accuracy: 0.6533 - val_loss: 0.6324 - val_accuracy: 0.7135
# Epoch 6/120
# 43/43 [==============================] - 246s 6s/step - loss: 0.6148 - accuracy: 0.6732 - val_loss: 0.6185 - val_accuracy: 0.7189
# Epoch 7/120
# 43/43 [==============================] - 244s 6s/step - loss: 0.6072 - accuracy: 0.6805 - val_loss: 0.6119 - val_accuracy: 0.7189
# Epoch 8/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.6029 - accuracy: 0.6926 - val_loss: 0.6038 - val_accuracy: 0.7060
# Epoch 9/120
# 43/43 [==============================] - 243s 6s/step - loss: 0.5991 - accuracy: 0.7063 - val_loss: 0.6134 - val_accuracy: 0.7242
# Epoch 10/120
# 43/43 [==============================] - 246s 6s/step - loss: 0.5961 - accuracy: 0.7132 - val_loss: 0.6227 - val_accuracy: 0.7210
# Epoch 11/120
# 43/43 [==============================] - 243s 6s/step - loss: 0.5946 - accuracy: 0.7121 - val_loss: 0.5884 - val_accuracy: 0.7350
# Epoch 12/120
# 43/43 [==============================] - 244s 6s/step - loss: 0.5902 - accuracy: 0.7114 - val_loss: 0.5904 - val_accuracy: 0.7521
# Epoch 13/120
# 43/43 [==============================] - 244s 6s/step - loss: 0.5812 - accuracy: 0.7276 - val_loss: 0.5863 - val_accuracy: 0.7468
# Epoch 14/120
# 43/43 [==============================] - 241s 6s/step - loss: 0.5787 - accuracy: 0.7173 - val_loss: 0.6134 - val_accuracy: 0.7264
# Epoch 15/120
# 43/43 [==============================] - 242s 6s/step - loss: 0.5854 - accuracy: 0.7206 - val_loss: 0.5883 - val_accuracy: 0.7457
# Epoch 16/120
# 43/43 [==============================] - 242s 6s/step - loss: 0.5720 - accuracy: 0.7261 - val_loss: 0.5804 - val_accuracy: 0.7500
# Epoch 17/120
# 43/43 [==============================] - 242s 6s/step - loss: 0.5717 - accuracy: 0.7342 - val_loss: 0.5732 - val_accuracy: 0.7532
# Epoch 18/120
# 43/43 [==============================] - 242s 6s/step - loss: 0.5646 - accuracy: 0.7390 - val_loss: 0.5741 - val_accuracy: 0.7436
# Epoch 19/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5612 - accuracy: 0.7496 - val_loss: 0.5702 - val_accuracy: 0.7436
# Epoch 20/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.5620 - accuracy: 0.7338 - val_loss: 0.5767 - val_accuracy: 0.7575
# Epoch 21/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.5587 - accuracy: 0.7415 - val_loss: 0.5582 - val_accuracy: 0.7500
# Epoch 22/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5502 - accuracy: 0.7441 - val_loss: 0.5471 - val_accuracy: 0.7650
# Epoch 23/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.5545 - accuracy: 0.7467 - val_loss: 0.5438 - val_accuracy: 0.7758
# Epoch 24/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5471 - accuracy: 0.7529 - val_loss: 0.5572 - val_accuracy: 0.7650
# Epoch 25/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.5437 - accuracy: 0.7493 - val_loss: 0.5633 - val_accuracy: 0.7629
# Epoch 26/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.5387 - accuracy: 0.7585 - val_loss: 0.5457 - val_accuracy: 0.7768
# Epoch 27/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5375 - accuracy: 0.7511 - val_loss: 0.5234 - val_accuracy: 0.7736
# Epoch 28/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5453 - accuracy: 0.7449 - val_loss: 0.5583 - val_accuracy: 0.7382
# Epoch 29/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.5499 - accuracy: 0.7265 - val_loss: 0.5644 - val_accuracy: 0.7210
# Epoch 30/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5390 - accuracy: 0.7430 - val_loss: 0.5387 - val_accuracy: 0.7672
# Epoch 31/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.5288 - accuracy: 0.7640 - val_loss: 0.5265 - val_accuracy: 0.7715
# Epoch 32/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5331 - accuracy: 0.7570 - val_loss: 0.5190 - val_accuracy: 0.7833
# Epoch 33/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5290 - accuracy: 0.7621 - val_loss: 0.5365 - val_accuracy: 0.7554
# Epoch 34/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5248 - accuracy: 0.7651 - val_loss: 0.5377 - val_accuracy: 0.7575
# Epoch 35/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5221 - accuracy: 0.7750 - val_loss: 0.5271 - val_accuracy: 0.7682
# Epoch 36/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5140 - accuracy: 0.7743 - val_loss: 0.5108 - val_accuracy: 0.7779
# Epoch 37/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5154 - accuracy: 0.7754 - val_loss: 0.5187 - val_accuracy: 0.7747
# Epoch 38/120
# 43/43 [==============================] - 250s 6s/step - loss: 0.5083 - accuracy: 0.7761 - val_loss: 0.5335 - val_accuracy: 0.7511
# Epoch 39/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.5096 - accuracy: 0.7743 - val_loss: 0.5222 - val_accuracy: 0.7661
# Epoch 40/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5059 - accuracy: 0.7739 - val_loss: 0.5229 - val_accuracy: 0.7629
# Epoch 41/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.5101 - accuracy: 0.7743 - val_loss: 0.4952 - val_accuracy: 0.7972
# Epoch 42/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.5084 - accuracy: 0.7699 - val_loss: 0.4948 - val_accuracy: 0.7886
# Epoch 43/120
# 43/43 [==============================] - 241s 6s/step - loss: 0.4972 - accuracy: 0.7882 - val_loss: 0.4957 - val_accuracy: 0.7854
# Epoch 44/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4957 - accuracy: 0.7779 - val_loss: 0.5284 - val_accuracy: 0.7500
# Epoch 45/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4939 - accuracy: 0.7761 - val_loss: 0.4913 - val_accuracy: 0.7886
# Epoch 46/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4929 - accuracy: 0.7824 - val_loss: 0.4937 - val_accuracy: 0.7822
# Epoch 47/120
# 43/43 [==============================] - 241s 6s/step - loss: 0.4929 - accuracy: 0.7794 - val_loss: 0.4835 - val_accuracy: 0.7918
# Epoch 48/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4929 - accuracy: 0.7794 - val_loss: 0.4856 - val_accuracy: 0.7865
# Epoch 49/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4915 - accuracy: 0.7772 - val_loss: 0.4862 - val_accuracy: 0.7897
# Epoch 50/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4859 - accuracy: 0.7787 - val_loss: 0.4800 - val_accuracy: 0.7822
# Epoch 51/120
# 43/43 [==============================] - 241s 6s/step - loss: 0.4877 - accuracy: 0.7820 - val_loss: 0.4852 - val_accuracy: 0.7843
# Epoch 52/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4885 - accuracy: 0.7809 - val_loss: 0.4880 - val_accuracy: 0.7800
# Epoch 53/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4920 - accuracy: 0.7757 - val_loss: 0.4964 - val_accuracy: 0.7704
# Epoch 54/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4821 - accuracy: 0.7857 - val_loss: 0.4878 - val_accuracy: 0.7886
# Epoch 55/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4851 - accuracy: 0.7857 - val_loss: 0.4798 - val_accuracy: 0.7897
# Epoch 56/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4755 - accuracy: 0.7937 - val_loss: 0.5100 - val_accuracy: 0.7500
# Epoch 57/120
# 43/43 [==============================] - 241s 6s/step - loss: 0.4809 - accuracy: 0.7835 - val_loss: 0.4960 - val_accuracy: 0.7693
# Epoch 58/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4768 - accuracy: 0.7824 - val_loss: 0.4751 - val_accuracy: 0.7843
# Epoch 59/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4730 - accuracy: 0.7860 - val_loss: 0.4755 - val_accuracy: 0.7929
# Epoch 60/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4684 - accuracy: 0.7893 - val_loss: 0.4689 - val_accuracy: 0.7918
# Epoch 61/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4777 - accuracy: 0.7901 - val_loss: 0.4688 - val_accuracy: 0.7876
# Epoch 62/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4735 - accuracy: 0.7849 - val_loss: 0.4942 - val_accuracy: 0.7758
# Epoch 63/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4732 - accuracy: 0.7864 - val_loss: 0.4678 - val_accuracy: 0.7940
# Epoch 64/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4732 - accuracy: 0.7812 - val_loss: 0.4928 - val_accuracy: 0.7629
# Epoch 65/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4663 - accuracy: 0.7912 - val_loss: 0.4621 - val_accuracy: 0.8047
# Epoch 66/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4654 - accuracy: 0.7919 - val_loss: 0.4631 - val_accuracy: 0.7908
# Epoch 67/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4634 - accuracy: 0.7904 - val_loss: 0.4551 - val_accuracy: 0.7918
# Epoch 68/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4684 - accuracy: 0.7879 - val_loss: 0.4911 - val_accuracy: 0.7822
# Epoch 69/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4683 - accuracy: 0.7857 - val_loss: 0.4766 - val_accuracy: 0.7704
# Epoch 70/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4667 - accuracy: 0.7893 - val_loss: 0.5117 - val_accuracy: 0.7446
# Epoch 71/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4649 - accuracy: 0.7901 - val_loss: 0.4636 - val_accuracy: 0.7876
# Epoch 72/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4602 - accuracy: 0.7882 - val_loss: 0.4625 - val_accuracy: 0.7865
# Epoch 73/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4554 - accuracy: 0.7901 - val_loss: 0.4645 - val_accuracy: 0.7843
# Epoch 74/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4573 - accuracy: 0.7949 - val_loss: 0.4519 - val_accuracy: 0.7940
# Epoch 75/120
# 43/43 [==============================] - 242s 6s/step - loss: 0.4549 - accuracy: 0.7930 - val_loss: 0.4592 - val_accuracy: 0.7822
# Epoch 76/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4520 - accuracy: 0.7989 - val_loss: 0.4419 - val_accuracy: 0.8069
# Epoch 77/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4569 - accuracy: 0.7893 - val_loss: 0.4467 - val_accuracy: 0.7983
# Epoch 78/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4505 - accuracy: 0.7941 - val_loss: 0.4326 - val_accuracy: 0.8058
# Epoch 79/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4541 - accuracy: 0.7945 - val_loss: 0.4703 - val_accuracy: 0.7682
# Epoch 80/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4474 - accuracy: 0.7982 - val_loss: 0.4384 - val_accuracy: 0.7994
# Epoch 81/120
# 43/43 [==============================] - 237s 6s/step - loss: 0.4461 - accuracy: 0.8037 - val_loss: 0.4518 - val_accuracy: 0.7876
# Epoch 82/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4437 - accuracy: 0.7996 - val_loss: 0.4455 - val_accuracy: 0.7951
# Epoch 83/120
# 43/43 [==============================] - 237s 6s/step - loss: 0.4459 - accuracy: 0.7978 - val_loss: 0.4442 - val_accuracy: 0.7983
# Epoch 84/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4384 - accuracy: 0.8062 - val_loss: 0.4317 - val_accuracy: 0.8165
# Epoch 85/120
# 43/43 [==============================] - 237s 6s/step - loss: 0.4383 - accuracy: 0.8051 - val_loss: 0.4353 - val_accuracy: 0.8090
# Epoch 86/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4420 - accuracy: 0.7993 - val_loss: 0.4266 - val_accuracy: 0.8058
# Epoch 87/120
# 43/43 [==============================] - 237s 6s/step - loss: 0.4283 - accuracy: 0.8114 - val_loss: 0.4221 - val_accuracy: 0.8208
# Epoch 88/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4275 - accuracy: 0.8132 - val_loss: 0.4854 - val_accuracy: 0.7500
# Epoch 89/120
# 43/43 [==============================] - 237s 6s/step - loss: 0.4339 - accuracy: 0.7974 - val_loss: 0.4634 - val_accuracy: 0.7758
# Epoch 90/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4318 - accuracy: 0.8092 - val_loss: 0.4189 - val_accuracy: 0.8155
# Epoch 91/120
# 43/43 [==============================] - 240s 6s/step - loss: 0.4170 - accuracy: 0.8165 - val_loss: 0.4287 - val_accuracy: 0.8090
# Epoch 92/120
# 43/43 [==============================] - 238s 6s/step - loss: 0.4181 - accuracy: 0.8151 - val_loss: 0.4229 - val_accuracy: 0.8219
# Epoch 93/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4280 - accuracy: 0.8085 - val_loss: 0.4422 - val_accuracy: 0.7876
# Epoch 94/120
# 43/43 [==============================] - 237s 6s/step - loss: 0.4220 - accuracy: 0.8103 - val_loss: 0.4535 - val_accuracy: 0.7876
# Epoch 95/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4221 - accuracy: 0.8158 - val_loss: 0.4260 - val_accuracy: 0.8026
# Epoch 96/120
# 43/43 [==============================] - 239s 6s/step - loss: 0.4111 - accuracy: 0.8173 - val_loss: 0.4507 - val_accuracy: 0.7908
# Epoch 97/120
# 43/43 [==============================] - 243s 6s/step - loss: 0.4219 - accuracy: 0.8103 - val_loss: 0.4230 - val_accuracy: 0.8047
# Epoch 98/120
# 43/43 [==============================] - 241s 6s/step - loss: 0.4128 - accuracy: 0.8217 - val_loss: 0.4334 - val_accuracy: 0.8026
# Epoch 99/120
# 43/43 [==============================] - 241s 6s/step - loss: 0.4060 - accuracy: 0.8224 - val_loss: 0.4134 - val_accuracy: 0.8230
# Epoch 100/120
# 43/43 [==============================] - 243s 6s/step - loss: 0.4064 - accuracy: 0.8257 - val_loss: 0.4347 - val_accuracy: 0.7886
# Epoch 101/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.4023 - accuracy: 0.8290 - val_loss: 0.4275 - val_accuracy: 0.8004
# Epoch 102/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.4193 - accuracy: 0.8107 - val_loss: 0.4427 - val_accuracy: 0.8004
# Epoch 103/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.4069 - accuracy: 0.8254 - val_loss: 0.4104 - val_accuracy: 0.8155
# Epoch 104/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.3967 - accuracy: 0.8298 - val_loss: 0.4233 - val_accuracy: 0.8069
# Epoch 105/120
# 43/43 [==============================] - 244s 6s/step - loss: 0.3999 - accuracy: 0.8228 - val_loss: 0.4329 - val_accuracy: 0.7918
# Epoch 106/120
# 43/43 [==============================] - 247s 6s/step - loss: 0.4220 - accuracy: 0.8026 - val_loss: 0.4437 - val_accuracy: 0.7854
# Epoch 107/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.4083 - accuracy: 0.8199 - val_loss: 0.4004 - val_accuracy: 0.8273
# Epoch 108/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.3917 - accuracy: 0.8335 - val_loss: 0.4153 - val_accuracy: 0.8101
# Epoch 109/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.3889 - accuracy: 0.8375 - val_loss: 0.4157 - val_accuracy: 0.8112
# Epoch 110/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.3956 - accuracy: 0.8313 - val_loss: 0.4058 - val_accuracy: 0.8219
# Epoch 111/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.3895 - accuracy: 0.8287 - val_loss: 0.4122 - val_accuracy: 0.8101
# Epoch 112/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.3826 - accuracy: 0.8382 - val_loss: 0.4096 - val_accuracy: 0.7983
# Epoch 113/120
# 43/43 [==============================] - 247s 6s/step - loss: 0.4026 - accuracy: 0.8294 - val_loss: 0.4094 - val_accuracy: 0.8058
# Epoch 114/120
# 43/43 [==============================] - 246s 6s/step - loss: 0.3932 - accuracy: 0.8313 - val_loss: 0.3989 - val_accuracy: 0.8165
# Epoch 115/120
# 43/43 [==============================] - 248s 6s/step - loss: 0.3920 - accuracy: 0.8169 - val_loss: 0.4326 - val_accuracy: 0.7876
# Epoch 116/120
# 43/43 [==============================] - 247s 6s/step - loss: 0.3902 - accuracy: 0.8268 - val_loss: 0.4031 - val_accuracy: 0.8112
# Epoch 117/120
# 43/43 [==============================] - 246s 6s/step - loss: 0.3762 - accuracy: 0.8375 - val_loss: 0.4003 - val_accuracy: 0.8122
# Epoch 118/120
# 43/43 [==============================] - 245s 6s/step - loss: 0.3862 - accuracy: 0.8313 - val_loss: 0.4092 - val_accuracy: 0.8079
# Epoch 119/120
# 43/43 [==============================] - 248s 6s/step - loss: 0.3722 - accuracy: 0.8500 - val_loss: 0.4239 - val_accuracy: 0.8079
# Epoch 120/120
# 43/43 [==============================] - 248s 6s/step - loss: 0.3779 - accuracy: 0.8401 - val_loss: 0.4104 - val_accuracy: 0.8155

# %%
plot_training(history,PLOT_PATH)

# %% [markdown]
# ### Salvar modelo

# %%
model.save(MODEL_PATH)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %% [markdown]
# ### Recuperar modelo salvo

# %%
model_recovered = load_model(MODEL_PATH)

# %% [markdown]
# ### Aplicar modelo aos dados de teste

# %%
y_pred = model_recovered.predict([X_test[:, 0], X_test[:, 1]])
# Out:
# 8/8 [==============================] - 4s 526ms/step

# %%
mapper_class = lambda value: 1 if value > 0.5 else 0

# %%
y_mapped = [ mapper_class(value) for value in  y_pred]
y_mapped = np.asarray(y_mapped).reshape(-1,1)

# %%
evaluation = abs(y_mapped - y_test)

# %%
acc = (evaluation.shape[0] - sum(evaluation))/evaluation.shape[0]

# %%
acc
# Out:
# array([0.83760684])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

cm= confusion_matrix(y_test, y_mapped)
sn.heatmap(cm, annot=True, fmt="d", cmap="binary")
plt.ylabel('Class Label')
plt.xlabel('Predicted Label')
plt.title('Matriz de confusão')


plt.savefig(FOLDER+'/confusion_matrix.png')

# %%
with open(ACC_PATH, 'w') as f:
    f.write("acc: {}\n".format(acc))
    f.write("batch size: {}\n".format(BATCH_SIZE))
    f.write("epochs: {}\n".format(EPOCHS))

# %%
with open(MODEL_INFO_PATH, 'w') as f:
    model_recovered.summary(print_fn=lambda x: f.write(x + '\n'))
